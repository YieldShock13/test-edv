# %% [markdown]
# <a href="https://colab.research.google.com/github/YieldShock13/test-edv/blob/main/Untitled255.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

# 1) Let's Load The Data

data = pd.read_csv("SPY Histroical Data (1).csv")

#2) Now we import the data from files, create the matrix, and drop n/a values.

returns = data [["Asset 1", "Asset 2"]].pct_change().dropna()
corr_matrix = returns.corr().to_numpy()

#3) Setting Simulation Parameters

S1_0 = 100.00, 100.00
mu1, mu2 = 0.02, 0.08
sigma1, sigma2 = 0.2, 0.8
T, N = 1.0, 252
dt = T/N

#4) Let's Generate Correlated Random Numbers

means = [0.0, 0.0]
epsilon = np.random.multivariate_normal(means, corr_matrix, size = N)
epsilon1 = [:, 0]
epsilon2 = [:, 1]

#5) Allocate Empty Memory Slots

S1 = np.zeros(N + 1)
S2 = np.zeros(N+1)
S1[0], S2[0], = S1_0, S2_0

#6) Executing the simulation loop
