# %% [markdown]
# <a href="https://colab.research.google.com/github/YieldShock13/test-edv/blob/main/Untitled115.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# =========================
# CONFIG
# =========================

DATA_START_DATE = "2005-01-01"      # for raw loading
REG_START_DATE  = "2008-11-14"      # target common start after backfill
END_DATE        = "2025-11-30"
FREQ            = "W-FRI"           # weekly on Fridays
PER_YR          = 52                # periods per year for weekly data

# --- File mapping: ticker -> CSV in current working dir
FILE_MAP = {
    # Portfolio names
    "AGLJ":  "AGLJ Historical Data.csv",
    "ABI":   "ABI Historical Data.csv",
    "BHPJ":  "BHP Historical Data.csv",           # use ADR for entire series
    "BIDJ":  "BIDJ Historical Data.csv",
    "BTIJ":  "BTIJ Historical Data.csv",
    "BVTJ":  "BVTJ Historical Data.csv",
    "CFRJ":  "CFRJ Historical Data.csv",
    "EMHJ":  "EMHJ Historical Data.csv",
    "REMJ":  "REMJ Historical Data.csv",
    "RNIJ":  "RNIJ Historical Data.csv",
    "SHPJ":  "SHPJ Historical Data.csv",
    "TBSJ":  "TBSJ Historical Data.csv",
    "VALJ":  "VALJ Historical Data (1).csv",
    # Benchmarks
    "JALSH":  "FTSE_JSE All Share Historical Data (1).csv",
    "JTOP40": "South Africa Top 40 Historical Data (1).csv",  # re-included Top40
}

# --- Current mark-to-market weights from statement (% of book, in decimals)
W_MTM = pd.Series({
    "AGLJ": 0.1071,   # Anglo American
    "ABI":  0.0282,   # Anheuser-Busch InBev
    "BHPJ": 0.0186,   # BHP
    "BIDJ": 0.0820,   # Bidcorp
    "BTIJ": 0.1328,   # British American Tobacco
    "BVTJ": 0.0764,   # Bidvest
    "CFRJ": 0.1688,   # Richemont
    "EMHJ": 0.0003,   # eMedia (tiny)
    "REMJ": 0.0698,   # Remgro
    "RNIJ": 0.1239,   # Reinet
    "SHPJ": 0.0918,   # Shoprite
    "TBSJ": 0.0721,   # Tiger Brands
    "VALJ": 0.0199,   # Valterra Platinum
}, dtype="float64")
W_MTM = W_MTM / W_MTM.sum()   # force to 1.0

# --- Cost-based weights: FROM STATEMENT (Total Cost column)
COST_VALUE_ZAR = {
    "AGLJ": 451_442.00,
    "ABI":  467_957.00,
    "BHPJ":      0.00,   # if cost is zero in statement, leave 0
    "BIDJ": 653_829.00,
    "BTIJ": 729_085.00,
    "BVTJ": 760_454.00,
    "CFRJ": 735_033.00,
    "EMHJ":   2_764.00,
    "REMJ": 481_854.00,
    "RNIJ": 623_667.00,
    "SHPJ":1_190_599.00,
    "TBSJ": 729_489.00,
    "VALJ": 172_612.00,
}
W_COST = pd.Series(COST_VALUE_ZAR, dtype="float64")
W_COST = W_COST / W_COST.sum()

# --- Dividend yield assumptions (simple constant annual yields, decimals)
DIV_YIELD_ANNUAL = {
    "AGLJ":  0.07,   # Anglo American
    "ABI":   0.025,  # ABI
    "BHPJ":  0.065,  # BHP
    "BIDJ":  0.024,  # Bidcorp
    "BTIJ":  0.075,  # BTI
    "BVTJ":  0.033,  # Bidvest
    "CFRJ":  0.022,  # Richemont
    "EMHJ":  0.09,   # eMedia (capped)
    "REMJ":  0.03,   # Remgro
    "RNIJ":  0.014,  # Reinet
    "SHPJ":  0.03,   # Shoprite
    "TBSJ":  0.05,   # Tiger Brands
    "VALJ":  0.08,   # Valterra
    "JALSH": 0.035,  # ALSI ~3.5%
    "JTOP40":0.03,   # Top40 ~3.0%
}

# --- 15% haircut on dividends (for separate line)
DIV_YIELD_85 = {k: v * 0.85 for k, v in DIV_YIELD_ANNUAL.items()}

# --- Risk-free rate assumption (annualised, decimal).
RF_ANN    = 0.07
RF_WEEKLY = (1 + RF_ANN)**(1 / PER_YR) - 1

# Benchmarks (for special outlier rules)
BENCH_TICKERS = ["JALSH", "JTOP40"]

# Portfolio universe tickers
PORT_TICKERS = sorted(W_MTM.index.tolist())

# =========================
# DATA HELPERS
# =========================

def load_investing_csv(filename):
    """Load an Investing.com-style CSV and return a daily price series."""
    df = pd.read_csv(filename)
    df.columns = [c.strip() for c in df.columns]
    if "Date" not in df.columns:
        raise ValueError(f"'Date' column not found in {filename}")
    # JSE downloads are usually day-first; this also handles US ADR safely enough.
    df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
    df = df.dropna(subset=["Date"]).sort_values("Date").set_index("Date")

    price_col = None
    for c in ["Price", "Close", "Last", "Close*"]:
        if c in df.columns:
            price_col = c
            break
    if price_col is None:
        raise ValueError(f"No price-like column in {filename}: {df.columns.tolist()}")

    s = pd.to_numeric(
        df[price_col].astype(str).str.replace(",", ""),
        errors="coerce"
    ).dropna()
    s.name = os.path.splitext(os.path.basename(filename))[0]
    return s

def to_weekly_returns(price, freq=FREQ):
    weekly = price.resample(freq).last().dropna()
    return weekly.pct_change().dropna()

def clean_stock_extremes(r, threshold=1.0):
    """
    For stocks: only treat |weekly return| >= threshold as corporate/split events.
    Those weeks are set to 0% return (mechanical adjustment).
    """
    if r.empty:
        return r, pd.Series(dtype=bool)
    big = r.abs() >= threshold
    r_clean = r.copy()
    r_clean[big] = 0.0
    return r_clean, big[big]

def add_dividends(weekly_ret, ticker, div_map):
    """Convert annual dividend yield into a flat weekly increment."""
    y_ann = div_map.get(ticker, 0.0)
    if y_ann == 0.0:
        return weekly_ret
    div_w = (1 + y_ann)**(1 / PER_YR) - 1
    return weekly_ret + div_w

# =========================
# LOAD ALL SERIES (WEEKLY RETURNS)
# =========================

print("Files in working dir:", os.listdir())

weekly_price_rets = {}
outlier_flags_100 = {}

for ticker, fname in FILE_MAP.items():
    if not os.path.exists(fname):
        print(f"WARNING: file for {ticker} not found: {fname}")
        continue

    s_price = load_investing_csv(fname)
    s_price = s_price.loc[DATA_START_DATE:END_DATE]

    s_ret = to_weekly_returns(s_price)

    if ticker in BENCH_TICKERS:
        # Benchmarks: NO winsorisation / corporate-event capping
        weekly_price_rets[ticker] = s_ret.copy()
        outlier_flags_100[ticker] = pd.Series(dtype=bool)
    else:
        # Stocks: only 100%+ weekly moves adjusted to 0%
        s_clean, flags_100 = clean_stock_extremes(s_ret)
        weekly_price_rets[ticker] = s_clean
        outlier_flags_100[ticker] = flags_100

# =========================
# BACKFILL BIDJ PRE-LISTING USING ALSI REGRESSION
# =========================

if "BIDJ" in weekly_price_rets and "JALSH" in weekly_price_rets:
    bidj_raw = weekly_price_rets["BIDJ"].dropna()
    jalsh_full = weekly_price_rets["JALSH"].dropna()

    common_idx = bidj_raw.index.intersection(jalsh_full.index)
    if len(common_idx) >= 52:  # at least a year of overlap
        X = jalsh_full.loc[common_idx].values
        y = bidj_raw.loc[common_idx].values
        # simple OLS y = alpha + beta * X
        X_mat = np.column_stack([np.ones_like(X), X])
        beta_vec = np.linalg.lstsq(X_mat, y, rcond=None)[0]
        alpha_hat, beta_hat = beta_vec[0], beta_vec[1]

        # Build synthetic BIDJ returns from REG_START_DATE up to first real BIDJ obs
        first_real = bidj_raw.index.min()
        pre_idx = jalsh_full.index[
            (jalsh_full.index >= pd.to_datetime(REG_START_DATE)) &
            (jalsh_full.index < first_real)
        ]
        synthetic = alpha_hat + beta_hat * jalsh_full.loc[pre_idx].values

        bidj_full = pd.concat([
            pd.Series(synthetic, index=pre_idx),
            bidj_raw
        ]).sort_index()

        weekly_price_rets["BIDJ"] = bidj_full
        print(f"\nBackfilled BIDJ using ALSI regression: alpha={alpha_hat:.6f}, beta={beta_hat:.3f}")
    else:
        print("WARNING: Not enough overlap to backfill BIDJ via ALSI regression.")
else:
    print("WARNING: BIDJ or JALSH missing; cannot backfill BIDJ.")

# =========================
# BUILD ALIGNED PANELS (PRICE RETURNS)
# =========================

price_panel = pd.DataFrame(weekly_price_rets).sort_index()
# Restrict to regression window and drop rows with any NaN
price_panel = price_panel.loc[REG_START_DATE:END_DATE].dropna(how="any")

print("\nAligned sample:")
print("Start:", price_panel.index[0], "End:", price_panel.index[-1])
print("Obs:", len(price_panel))

print("\nRegression start dates (weekly, after NaN drop):")
for t in price_panel.columns:
    print(f"{t}: {price_panel[t].first_valid_index().date()}")

# =========================
# TOTAL-RETURN PANELS
# =========================

# Original dividend assumptions
weekly_total_rets = {}
weekly_total_rets_85 = {}

for t in price_panel.columns:
    base_ret = price_panel[t]
    weekly_total_rets[t]    = add_dividends(base_ret, t, DIV_YIELD_ANNUAL)
    weekly_total_rets_85[t] = add_dividends(base_ret, t, DIV_YIELD_85)

total_panel    = pd.DataFrame(weekly_total_rets).loc[price_panel.index]
total_panel_85 = pd.DataFrame(weekly_total_rets_85).loc[price_panel.index]

# =========================
# PORTFOLIO CONSTRUCTION
# =========================

PORT_TICKERS_IN_PANEL = [t for t in PORT_TICKERS if t in price_panel.columns]

price_port   = price_panel[PORT_TICKERS_IN_PANEL]
total_port   = total_panel[PORT_TICKERS_IN_PANEL]
total_port_85= total_panel_85[PORT_TICKERS_IN_PANEL]

W_MTM_use  = W_MTM.reindex(PORT_TICKERS_IN_PANEL).fillna(0.0)
W_MTM_use  = W_MTM_use / W_MTM_use.sum()

W_COST_use = W_COST.reindex(PORT_TICKERS_IN_PANEL).fillna(0.0)
W_COST_use = W_COST_use / W_COST_use.sum()

def portfolio_return(ret_df, weights: pd.Series):
    return (ret_df * weights.values).sum(axis=1)

# Price-only portfolios
rp_mtm_price  = portfolio_return(price_port, W_MTM_use)
rp_cost_price = portfolio_return(price_port, W_COST_use)

# Total-return portfolios (original dividend assumptions)
rp_mtm_total  = portfolio_return(total_port, W_MTM_use)
rp_cost_total = portfolio_return(total_port, W_COST_use)

# Total-return portfolios (15% dividend haircut)
rp_mtm_total_85  = portfolio_return(total_port_85, W_MTM_use)
rp_cost_total_85 = portfolio_return(total_port_85, W_COST_use)

# Benchmarks
rb_jalsh_price = price_panel["JALSH"]
rb_top40_price = price_panel["JTOP40"]

rb_jalsh_total    = total_panel["JALSH"]
rb_top40_total    = total_panel["JTOP40"]
rb_jalsh_total_85 = total_panel_85["JALSH"]
rb_top40_total_85 = total_panel_85["JTOP40"]

print("\n== PORTFOLIO WEIGHTS USED (MTM, % of equity) ==")
print((W_MTM_use * 100).round(2))

print("\n== PORTFOLIO WEIGHTS USED (COST-BASED, % of equity) ==")
print((W_COST_use * 100).round(2))

# =========================
# RISK METRICS
# =========================

def cagr(r):
    if len(r) == 0:
        return np.nan
    cum = (1 + r).prod()
    yrs = len(r) / PER_YR
    return cum**(1/yrs) - 1

def ann_vol(r):
    return r.std(ddof=1) * np.sqrt(PER_YR)

def sharpe_ratio(r, rf_weekly=RF_WEEKLY):
    ex = r - rf_weekly
    denom = r.std(ddof=1)
    if denom == 0:
        return np.nan
    return (ex.mean() * PER_YR) / (denom * np.sqrt(PER_YR))

def max_drawdown(r):
    curve = (1 + r).cumprod()
    peak  = curve.cummax()
    dd    = (curve / peak) - 1.0
    return dd.min()

def hist_var(r, alpha=0.05):
    return np.quantile(r, alpha)

def capm_stats(r_p, r_m, rf_weekly=RF_WEEKLY):
    ex_p = r_p - rf_weekly
    ex_m = r_m - rf_weekly
    cov  = np.cov(ex_p, ex_m)[0, 1]
    varm = np.var(ex_m)
    if varm <= 0:
        beta = np.nan
    else:
        beta = cov / varm
    alpha_weekly = ex_p.mean() - beta * ex_m.mean() if not np.isnan(beta) else np.nan
    alpha_ann    = (1 + alpha_weekly)**PER_YR - 1 if not np.isnan(alpha_weekly) else np.nan
    te           = ann_vol(ex_p - ex_m)
    return beta, alpha_ann, te

def summarise(r, name, bench=None):
    d = {
        "CAGR":   cagr(r),
        "AnnVol": ann_vol(r),
        "Sharpe": sharpe_ratio(r),
        "MaxDD":  max_drawdown(r),
        "VaR_5pc":hist_var(r, 0.05),
    }
    if bench is not None:
        beta, alpha_ann, te = capm_stats(r, bench)
        d["Beta_vs_bench"] = beta
        d["Alpha_ann"]     = alpha_ann
        d["TE"]            = te

    # convert to % where appropriate
    pct_keys = ["CAGR", "AnnVol", "MaxDD", "VaR_5pc", "Alpha_ann", "TE"]
    for k in pct_keys:
        if k in d and d[k] is not None and not np.isnan(d[k]):
            d[k] = d[k] * 100.0
    return pd.Series(d, name=name)

summaries = []

# price-only vs ALSI
summaries.append(summarise(rp_mtm_price,  "Port_MTM_price_vs_ALSI",  bench=rb_jalsh_price))
summaries.append(summarise(rp_cost_price, "Port_COST_price_vs_ALSI", bench=rb_jalsh_price))
summaries.append(summarise(rb_jalsh_price,"ALSI_price",              bench=rb_jalsh_price))
summaries.append(summarise(rb_top40_price,"Top40_price",             bench=rb_jalsh_price))

# total-return vs ALSI total
summaries.append(summarise(rp_mtm_total,  "Port_MTM_total_vs_ALSI",  bench=rb_jalsh_total))
summaries.append(summarise(rp_cost_total, "Port_COST_total_vs_ALSI", bench=rb_jalsh_total))
summaries.append(summarise(rb_jalsh_total,"ALSI_total",              bench=rb_jalsh_total))
summaries.append(summarise(rb_top40_total,"Top40_total",             bench=rb_jalsh_total))

summary_table = pd.DataFrame(summaries)
print("\nRisk / performance summary (weekly data, annualised; % except Sharpe/Beta):")
print(summary_table.round(3))

# =========================
# ROLLING AVERAGE CORRELATION OF CONSTITUENTS
# =========================

def rolling_avg_corr(ret_df: pd.DataFrame, window: int = 52) -> pd.Series:
    """
    Rolling average pairwise correlation of all columns in ret_df.
    Implemented manually (no rolling.apply), so no Series.corr() error.
    """
    ret_df = ret_df.dropna(how="any")
    idx = ret_df.index
    n   = len(idx)
    out = pd.Series(np.nan, index=idx, name=f"AvgCorr_{window}w")

    if n < window:
        return out

    for i in range(window - 1, n):
        win = ret_df.iloc[i - window + 1 : i + 1]
        c   = win.corr()
        vals = c.values
        iu   = np.triu_indices_from(vals, k=1)
        if len(iu[0]) == 0:
            out.iloc[i] = np.nan
        else:
            out.iloc[i] = np.nanmean(vals[iu])
    return out

roll_corr_price = rolling_avg_corr(price_port, window=52)
roll_corr_total = rolling_avg_corr(total_port, window=52)

# =========================
# EQUITY CURVES & CHARTS
# =========================

def equity_curve(r, name):
    return (1 + r).cumprod().rename(name)

# Price-only equity curves
eq_price = pd.concat([
    equity_curve(rp_mtm_price,  "Port_MTM_price"),
    equity_curve(rp_cost_price, "Port_COST_price"),
    equity_curve(rb_jalsh_price,"ALSI_price"),
    equity_curve(rb_top40_price,"Top40_price"),
], axis=1)

# Total-return equity curves (original divs)
eq_total = pd.concat([
    equity_curve(rp_mtm_total,  "Port_MTM_total"),
    equity_curve(rp_cost_total, "Port_COST_total"),
    equity_curve(rb_jalsh_total,"ALSI_total"),
    equity_curve(rb_top40_total,"Top40_total"),
], axis=1)

plt.figure(figsize=(10, 6))
eq_price.plot(ax=plt.gca())
plt.title(f"Equity Curves (Price Returns, {REG_START_DATE}–{END_DATE})")
plt.ylabel("Growth of 1")
plt.xlabel("Date")
plt.grid(True)
plt.tight_layout()
plt.show()

# Total-return equity curve + 15% dividend haircut as separate dashed lines
plt.figure(figsize=(10, 6))

# Original curves
eq_total.plot(ax=plt.gca(), linewidth=1.8)

# Haircut curves
equity_curve(rp_mtm_total_85,  "Port_MTM_total_85").plot(linestyle="--")
equity_curve(rp_cost_total_85, "Port_COST_total_85").plot(linestyle="--")
equity_curve(rb_jalsh_total_85,"ALSI_total_85").plot(linestyle="--")
equity_curve(rb_top40_total_85,"Top40_total_85").plot(linestyle="--")

plt.title("Equity Curves (Total Returns) — Original vs 15% Dividend Haircut")
plt.ylabel("Growth of 1")
plt.xlabel("Date")
plt.grid(True)
plt.tight_layout()
plt.show()

# Rolling average correlation (price)
plt.figure(figsize=(10, 4))
roll_corr_price.plot()
plt.title("Rolling 52-week average pairwise correlation (price returns)")
plt.xlabel("Date")
plt.ylabel("Avg pairwise corr")
plt.grid(True)
plt.tight_layout()
plt.show()

# Rolling average correlation (total)
plt.figure(figsize=(10, 4))
roll_corr_total.plot()
plt.title("Rolling 52-week average pairwise correlation (total returns)")
plt.xlabel("Date")
plt.ylabel("Avg pairwise corr")
plt.grid(True)
plt.tight_layout()
plt.show()

# =========================
# OUTLIER REPORT
# =========================

print("\nNumber of flagged 100%+ weekly-move weeks per STOCK ticker:")
for t, flags in outlier_flags_100.items():
    if t in BENCH_TICKERS:
        continue
    print(f"{t}: {len(flags)}")

print("\nWeeks with |weekly return| > 100% AFTER cleaning (should be tiny / zero for stocks):")
for t in price_panel.columns:
    big = price_panel[t].loc[abs(price_panel[t]) > 1.0]
    print(f"{t}: {len(big)}")
# Out:
# Files in working dir: ['.config', '900415_StatementData_0.pdf', 'ABI Historical Data.csv', 'VALJ Historical Data (1).csv', 'BHGJ Historical Data.csv', 'RNIJ Historical Data.csv', 'BVTJ Historical Data.csv', 'J203_20251031.pdf', 'South Africa Top 40 Historical Data (1).csv', 'BTIJ Historical Data.csv', 'BHP Historical Data.csv', 'TBSJ Historical Data.csv', 'SHPJ Historical Data.csv', 'HistoricalData_1764515725863.csv', 'CFRJ Historical Data.csv', 'Dividends 20180207.xls', 'CFR Historical Data.csv', 'SYGT40J Historical Data.csv', 'AGLJ Historical Data.csv', 'BIDJ Historical Data.csv', 'J259_20251031.pdf', 'STXGOVJ Historical Data (3).csv', 'REMJ Historical Data.csv', 'BHP Historical Data (1).csv', 'EMHJ Historical Data.csv', 'STXGOVJ Historical Data (2).csv', 'FTSE_JSE All Share Historical Data (1).csv', 'sample_data']
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# /tmp/ipython-input-3751884030.py:117: UserWarning: Parsing dates in %Y/%m/%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
# Backfilled BIDJ using ALSI regression: alpha=0.000272, beta=0.789
#
# Aligned sample:
# Start: 2008-11-14 00:00:00 End: 2025-11-28 00:00:00
# Obs: 839
#
# Regression start dates (weekly, after NaN drop):
# AGLJ: 2008-11-14
# ABI: 2008-11-14
# BHPJ: 2008-11-14
# BIDJ: 2008-11-14
# BTIJ: 2008-11-14
# BVTJ: 2008-11-14
# CFRJ: 2008-11-14
# EMHJ: 2008-11-14
# REMJ: 2008-11-14
# RNIJ: 2008-11-14
# SHPJ: 2008-11-14
# TBSJ: 2008-11-14
# VALJ: 2008-11-14
# JALSH: 2008-11-14
# JTOP40: 2008-11-14
#
# == PORTFOLIO WEIGHTS USED (MTM, % of equity) ==
# ABI      2.84
# AGLJ    10.80
# BHPJ     1.88
# BIDJ     8.27
# BTIJ    13.39
# BVTJ     7.70
# CFRJ    17.02
# EMHJ     0.03
# REMJ     7.04
# RNIJ    12.49
# SHPJ     9.26
# TBSJ     7.27
# VALJ     2.01
# dtype: float64
#
# == PORTFOLIO WEIGHTS USED (COST-BASED, % of equity) ==
# ABI      6.69
# AGLJ     6.45
# BHPJ     0.00
# BIDJ     9.34
# BTIJ    10.42
# BVTJ    10.87
# CFRJ    10.50
# EMHJ     0.04
# REMJ     6.88
# RNIJ     8.91
# SHPJ    17.01
# TBSJ    10.42
# VALJ     2.47
# dtype: float64
#
# Risk / performance summary (weekly data, annualised; % except Sharpe/Beta):
#                            CAGR  AnnVol  Sharpe   MaxDD  VaR_5pc  \
# Port_MTM_price_vs_ALSI   10.954  15.337   0.314 -32.798   -2.681
# Port_COST_price_vs_ALSI  10.704  14.874   0.304 -41.856   -2.784
# ALSI_price                7.888  16.716   0.134 -33.585   -3.210
# Top40_price               7.898  17.826   0.137 -32.089   -3.427
# Port_MTM_total_vs_ALSI   15.326  15.337   0.567 -29.285   -2.606
# Port_COST_total_vs_ALSI  14.858  14.874   0.552 -36.301   -2.713
# ALSI_total               11.659  16.716   0.340 -31.318   -3.144
# Top40_total              11.131  17.826   0.302 -30.793   -3.370
#
#                          Beta_vs_bench  Alpha_ann     TE
# Port_MTM_price_vs_ALSI           0.789      3.098  8.609
# Port_COST_price_vs_ALSI          0.736      2.916  9.484
# ALSI_price                       1.001     -0.003  0.000
# Top40_price                      1.063      0.059  1.900
# Port_MTM_total_vs_ALSI           0.789      4.297  8.609
# Port_COST_total_vs_ALSI          0.736      4.115  9.484
# ALSI_total                       1.001     -0.007  0.000
# Top40_total                      1.063     -0.642  1.900
# Number of flagged 100%+ weekly-move weeks per STOCK ticker:
# AGLJ: 0
# ABI: 0
# BHPJ: 0
# BIDJ: 0
# BTIJ: 0
# BVTJ: 0
# CFRJ: 1
# EMHJ: 1
# REMJ: 0
# RNIJ: 0
# SHPJ: 0
# TBSJ: 0
# VALJ: 0
#
# Weeks with |weekly return| > 100% AFTER cleaning (should be tiny / zero for stocks):
# AGLJ: 0
# ABI: 0
# BHPJ: 0
# BIDJ: 0
# BTIJ: 0
# BVTJ: 0
# CFRJ: 0
# EMHJ: 0
# REMJ: 0
# RNIJ: 0
# SHPJ: 0
# TBSJ: 0
# VALJ: 0
# JALSH: 0
# JTOP40: 0
